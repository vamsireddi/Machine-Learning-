# %% [markdown]
# <a href="https://colab.research.google.com/github/vamsireddi/Machine-Learning-/blob/main/Intro_to_MachineLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My Drive/
# Out:
# Mounted at /content/drive
# /content/drive/My Drive

# %%
df = pd.read_csv('FastFoodRestaurants.csv')

# %%
df.address.head()
# Out:
# 0              324 Main St
# 1          530 Clinton Ave
# 2     408 Market Square Dr
# 3    6098 State Highway 37
# 4          139 Columbus Rd
# Name: address, dtype: object

# %%
df.head()
# Out:
#                  address                    city country  \
# 0            324 Main St                 Massena      US
# 1        530 Clinton Ave  Washington Court House      US
# 2   408 Market Square Dr               Maysville      US
# 3  6098 State Highway 37                 Massena      US
# 4        139 Columbus Rd                  Athens      US
#
#                                                 keys  latitude  longitude  \
# 0                us/ny/massena/324mainst/-1161002137  44.92130  -74.89021
# 1  us/oh/washingtoncourthouse/530clintonave/-7914...  39.53255  -83.44526
# 2       us/ky/maysville/408marketsquaredr/1051460804  38.62736  -83.79141
# 3       us/ny/massena/6098statehighway37/-1161002137  44.95008  -74.84553
# 4               us/oh/athens/139columbusrd/990890980  39.35155  -82.09728
#
#                name postalCode province  \
# 0        McDonald's      13662       NY
# 1           Wendy's      43160       OH
# 2  Frisch's Big Boy      41056       KY
# ...

# %%
df.head(10)
# Out:
#                          address                    city country  \
# 0                    324 Main St                 Massena      US
# 1                530 Clinton Ave  Washington Court House      US
# 2           408 Market Square Dr               Maysville      US
# 3          6098 State Highway 37                 Massena      US
# 4                139 Columbus Rd                  Athens      US
# 5                 4182 Tonya Trl                Hamilton      US
# 6                  590 S Main St               Englewood      US
# 7              401 N Jennings St                  Saluda      US
# 8                205 W Church St               Batesburg      US
# 9  2711 W. Kings Highway Ste. 18               Paragould      US
#
#                                                 keys  latitude  longitude  \
# 0                us/ny/massena/324mainst/-1161002137  44.92130  -74.89021
# 1  us/oh/washingtoncourthouse/530clintonave/-7914...  39.53255  -83.44526
# ...

# %%
df.shape
# Out:
# (10000, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   address     10000 non-null  object
#  1   city        10000 non-null  object
#  2   country     10000 non-null  object
#  3   keys        10000 non-null  object
#  4   latitude    10000 non-null  float64
#  5   longitude   10000 non-null  float64
#  6   name        10000 non-null  object
#  7   postalCode  10000 non-null  object
#  8   province    10000 non-null  object
#  9   websites    9535 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 781.4+ KB

# %%
df.describe()
# Out:
#            latitude     longitude
# count  10000.000000  10000.000000
# mean      37.552195    -91.056132
# std        5.050275     18.556339
# min       -6.244273   -159.378915
# 25%       34.028706    -97.412631
# 50%       38.298216    -87.660930
# 75%       41.116765    -81.458351
# max       64.840240    123.012361

# %%
df.isnull().sum()
# Out:
# address         0
# city            0
# country         0
# keys            0
# latitude        0
# longitude       0
# name            0
# postalCode      0
# province        0
# websites      465
# dtype: int64

# %%
df.loc[53]
# Out:
# address                           5680 Commercial St SE Ste 100
# city                                                      Salem
# country                                                      US
# keys           us/or/salem/5680commercialstseste100/-1055723171
# latitude                                               44.87205
# longitude                                            -123.02243
# name                                             Domino's Pizza
# postalCode                                                97306
# province                                                     OR
# websites      https://www.dominos.com/en/?redirect=homepage,...
# Name: 53, dtype: object

# %%
df.plot()

# %%
df.tail()
# Out:
#                     address            city country  \
# 9995  3013 Peach Orchard Rd         Augusta      US
# 9996      678 Northwest Hwy            Cary      US
# 9997           1708 Main St        Longmont      US
# 9998      67740 Highway 111  Cathedral City      US
# 9999    5701 E La Palma Ave         Anaheim      US
#
#                                                 keys   latitude   longitude  \
# 9995     us/ga/augusta/3013peachorchardrd/-791445730  33.415257  -82.024531
# 9996            us/il/cary/678northwesthwy/787691191  42.217300  -88.255800
# 9997            us/co/longmont/1708mainst/-448666054  40.189190 -105.101720
# 9998  us/ca/cathedralcity/67740highway111/-981164808  33.788640 -116.482150
# 9999         us/ca/anaheim/5701elapalmaave/554191587  33.860074 -117.789762
#
#                              name postalCode province  \
# 9995                      Wendy's      30906       GA
# 9996  Lee's Oriental Martial Arts      60013       IL
# ...

# %%
df.tail(10)
# Out:
#                      address            city country  \
# 9990        6910 Ritchie Hwy     Glen Burnie      US
# 9991  1122 SE Hawthorne Blvd        Portland      US
# 9992  310 Daniel Webster Hwy          Nashua      US
# 9993         3956 Guthrie St    East Chicago      US
# 9994           3823 Guess Rd          Durham      US
# 9995   3013 Peach Orchard Rd         Augusta      US
# 9996       678 Northwest Hwy            Cary      US
# 9997            1708 Main St        Longmont      US
# 9998       67740 Highway 111  Cathedral City      US
# 9999     5701 E La Palma Ave         Anaheim      US
#
#                                                 keys   latitude   longitude  \
# 9990      us/md/glenburnie/6910ritchiehwy/-791445730  39.186102  -76.612795
# 9991  us/or/portland/1122sehawthorneblvd/-2013151130  45.512000 -122.653960
# 9992      us/nh/nashua/310danielwebsterhwy/387392632  42.701994  -71.440706
# ...

# %%
df.sample(6)
# Out:
#                                address             city country  \
# 6708                 18320 SE Stark St         Portland      US
# 4768  4975 W Irlo Bronson Memorial Hwy        Kissimmee      US
# 9330                 307 Cherokee Blvd      Chattanooga      US
# 5012                    26 Railroad St  Saint Johnsbury      US
# 9519              11619 SW Pacific Hwy         Portland      US
# 4720                       16 W 8th St         New York      US
#
#                                                    keys   latitude  \
# 6708          us/or/portland/18320sestarkst/-1161002137  45.518568
# 4768  us/fl/kissimmee/4975wirlobronsonmemorialhwy/34...  28.333628
# 9330       us/tn/chattanooga/307cherokeeblvd/-442344130  35.065040
# 5012       us/vt/saintjohnsbury/26railroadst/-891525969  44.412902
# 9519       us/or/portland/11619swpacifichwy/-1130994620  45.438850
# 4720                 us/ny/newyork/16w8thst/-1055723171  40.732586
#
# ...
