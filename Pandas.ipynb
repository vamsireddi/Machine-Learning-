# %% [markdown]
# <a href="https://colab.research.google.com/github/vamsireddi/Machine-Learning-/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = [['apple', 10, 240], ['orange', 15, 150], ['grapes', 14, 80], ['pineapple', 10, 70]]
df1 = pd.DataFrame(data, columns = ['Fruit_name', 'Quantity', 'Unit_price'])
df1
# Out:
#   Fruit_name  Quantity  Unit_price
# 0      apple        10         240
# 1     orange        15         150
# 2     grapes        14          80
# 3  pineapple        10          70

# %%
data = {'Fruit_name':['apple', 'orange', 'grapes', 'pineapple'], 'Quantity':[10, 15, 14, 10], 'Unit_price':[240, 150, 80, 70]}
df2 = pd.DataFrame(data)
df2
# Out:
#   Fruit_name  Quantity  Unit_price
# 0      apple        10         240
# 1     orange        15         150
# 2     grapes        14          80
# 3  pineapple        10          70

# %%
data = {'Fruit_name':['apple', 'orange', 'grapes', 'pineapple'], 'Quantity':[10, 15, 14, 10], 'Unit_price':[240, 150, 80, 70]}
df3 = pd.DataFrame(data, index=['f1', 'f2', 'f3', 'f4'])
df3
# Out:
#    Fruit_name  Quantity  Unit_price
# f1      apple        10         240
# f2     orange        15         150
# f3     grapes        14          80
# f4  pineapple        10          70

# %%
data = [{'Fruit_name':'apple', 'Quantity':10, 'Unit_price':240}, {'Fruit_name':'orange', 'Quantity':15, 'Unit_price':150}, {'Fruit_name':'grapes', 'Quantity':14, 'Unit_price':80}, {'Fruit_name':'pineapple', 'Quantity':10, 'Unit_price':70}]
df4 = pd.DataFrame(data)
df4
# Out:
#   Fruit_name  Quantity  Unit_price
# 0      apple        10         240
# 1     orange        15         150
# 2     grapes        14          80
# 3  pineapple        10          70

# %%
row =  [{'Fruit_name':'apple', 'Quantity':10, 'Unit_price':240}, {'Fruit_name':'orange', 'Quantity':15, 'Unit_price':150}, {'Fruit_name':'grapes', 'Quantity':14, 'Unit_price':80}, {'Fruit_name':'pineapple', 'Quantity':10, 'Unit_price':70}]
df4 = df4.append(row, ignore_index=True)
df4
# Out:
#   Fruit_name  Quantity  Unit_price
# 0      apple        10         240
# 1     orange        15         150
# 2     grapes        14          80
# 3  pineapple        10          70
# 4     cherry         5         500
# 5      apple        10         240
# 6     orange        15         150
# 7     grapes        14          80
# 8  pineapple        10          70

# %%
df4.index
df4.loc[len(df4.index)] = ['cherry', 5, 500]
df4
# Out:
#   Fruit_name  Quantity  Unit_price
# 0      apple        10         240
# 1     orange        15         150
# 2     grapes        14          80
# 3  pineapple        10          70
# 4     cherry         5         500
# 5      apple        10         240
# 6     orange        15         150
# 7     grapes        14          80
# 8  pineapple        10          70
# 9     cherry         5         500

# %%
data = [{'Fruit_name':'mango', 'Quantity':13, 'Unit_price':140}, {'Fruit_name':'strawberry', 'Quantity':8, 'Unit_price':250}]
df5 = pd.DataFrame(data)
df4 = pd.concat([df4, df5], ignore_index=True)
df4
# Out:
#    Fruit_name  Quantity  Unit_price
# 0       apple        10         240
# 1      orange        15         150
# 2      grapes        14          80
# 3   pineapple        10          70
# 4      litchy        10          80
# 5      cherry         5         500
# 6       mango        13         140
# 7  strawberry         8         250

# %%
df4['Total_price'] = df4['Quantity'] * df4['Unit_price']
df4
# Out:
#   Fruit_name  Quantity  Unit_price  Total_price
# 0      apple        10         240         2400
# 1     orange        15         150         2250
# 2     grapes        14          80         1120
# 3  pineapple        10          70          700
# 4     cherry         5         500         2500
# 5      apple        10         240         2400
# 6     orange        15         150         2250
# 7     grapes        14          80         1120
# 8  pineapple        10          70          700
# 9     cherry         5         500         2500

# %%
df4.columns = ['Fruit', 'Qty', 'Uprice', 'Totprice']
df4
# Out:
#        Fruit  Qty  Uprice  Totprice
# 0      apple   10     240      2400
# 1     orange   15     150      2250
# 2     grapes   14      80      1120
# 3  pineapple   10      70       700
# 4     cherry    5     500      2500
# 5      apple   10     240      2400
# 6     orange   15     150      2250
# 7     grapes   14      80      1120
# 8  pineapple   10      70       700
# 9     cherry    5     500      2500

# %%
df4 = df4.rename(columns = {"Fruit":"Fruitname"})
df4
# Out:
#    Fruitname  Qty  Uprice  Totprice
# 0      apple   10     240      2400
# 1     orange   15     150      2250
# 2     grapes   14      80      1120
# 3  pineapple   10      70       700
# 4     cherry    5     500      2500
# 5      apple   10     240      2400
# 6     orange   15     150      2250
# 7     grapes   14      80      1120
# 8  pineapple   10      70       700
# 9     cherry    5     500      2500

# %%
df4 = df4.rename({'Qty':'Quantity', 'Uprice':'Unitprice'}, axis = 'columns')
df4
# Out:
#    Fruitname  Quantity  Unitprice  Totprice
# 0      apple        10        240      2400
# 1     orange        15        150      2250
# 2     grapes        14         80      1120
# 3  pineapple        10         70       700
# 4     cherry         5        500      2500
# 5      apple        10        240      2400
# 6     orange        15        150      2250
# 7     grapes        14         80      1120
# 8  pineapple        10         70       700
# 9     cherry         5        500      2500

# %%
df4 = df4.sort_index()
df4
# Out:
#    Fruitname  Quantity  Unitprice  Totprice
# 0      apple        10        240      2400
# 1     orange        15        150      2250
# 2     grapes        14         80      1120
# 3  pineapple        10         70       700
# 4     cherry         5        500      2500
# 5      apple        10        240      2400
# 6     orange        15        150      2250
# 7     grapes        14         80      1120
# 8  pineapple        10         70       700
# 9     cherry         5        500      2500

# %%
df4 = df4.sort_index(ascending=False)
df4
# Out:
#    Fruitname  Quantity  Unitprice  Totprice
# 9     cherry         5        500      2500
# 8  pineapple        10         70       700
# 7     grapes        14         80      1120
# 6     orange        15        150      2250
# 5      apple        10        240      2400
# 4     cherry         5        500      2500
# 3  pineapple        10         70       700
# 2     grapes        14         80      1120
# 1     orange        15        150      2250
# 0      apple        10        240      2400

# %%
df4 = df4.sort_index(axis=1)
df4
# Out:
#    Fruitname  Quantity  Totprice  Unitprice
# 9     cherry         5      2500        500
# 8  pineapple        10       700         70
# 7     grapes        14      1120         80
# 6     orange        15      2250        150
# 5      apple        10      2400        240
# 4     cherry         5      2500        500
# 3  pineapple        10       700         70
# 2     grapes        14      1120         80
# 1     orange        15      2250        150
# 0      apple        10      2400        240

# %%
df4 = df4.sort_index(ascending=False, axis=1)
df4
# Out:
#    Unitprice  Totprice  Quantity  Fruitname
# 9        500      2500         5     cherry
# 8         70       700        10  pineapple
# 7         80      1120        14     grapes
# 6        150      2250        15     orange
# 5        240      2400        10      apple
# 4        500      2500         5     cherry
# 3         70       700        10  pineapple
# 2         80      1120        14     grapes
# 1        150      2250        15     orange
# 0        240      2400        10      apple

# %%
s1 = pd.Series(['apple', 'lenovo', 'samsung', 'acer', 'dell'], name = 'Brand')
s2 = pd.Series([100000, 35000, 40000, 42000, 28000], name = 'price')
print(s1)
print(s2)
# Out:
# 0      apple
# 1     lenovo
# 2    samsung
# 3       acer
# 4       dell
# Name: Brand, dtype: object
# 0    100000
# 1     35000
# 2     40000
# 3     42000
# 4     28000
# Name: price, dtype: int64

# %%
df6 = pd.merge(s1, s2, left_index=True, right_index=True)
df6
# Out:
#      Brand   price
# 0    apple  100000
# 1   lenovo   35000
# 2  samsung   40000
# 3     acer   42000
# 4     dell   28000

# %%
df7 = s1.to_frame()
df7
# Out:
#      Brand
# 0    apple
# 1   lenovo
# 2  samsung
# 3     acer
# 4     dell

# %%
df8 = s1.to_frame().reset_index()
df8
# Out:
#    index    Brand
# 0      0    apple
# 1      1   lenovo
# 2      2  samsung
# 3      3     acer
# 4      4     dell

# %%
iris = 'http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
df = pd.read_csv(iris, sep=',', names = names)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='object')

# %%
df.head(15)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# 12           4.8          3.0           1.4          0.1  Iris-setosa
# 13           4.3          3.0           1.1          0.1  Iris-setosa
# 14           5.8          4.0           1.2          0.2  Iris-setosa

# %%
df.tail(6)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.sample(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            class
# 98            5.1          2.5           3.0          1.1  Iris-versicolor
# 27            5.2          3.5           1.5          0.2      Iris-setosa
# 134           6.1          2.6           5.6          1.4   Iris-virginica
# 34            4.9          3.1           1.5          0.1      Iris-setosa
# 96            5.7          2.9           4.2          1.3  Iris-versicolor
# 41            4.5          2.3           1.3          0.3      Iris-setosa
# 89            5.5          2.5           4.0          1.3  Iris-versicolor
# 30            4.8          3.1           1.6          0.2      Iris-setosa
# 17            5.1          3.5           1.4          0.3      Iris-setosa
# 126           6.2          2.8           4.8          1.8   Iris-virginica

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# class            object
# dtype: object

# %%
df['sepal_length'].dtype
# Out:
# dtype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df['class'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: class, dtype: int64

# %%
df['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['class'].nunique()
# Out:
# 3

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df[df.duplicated()]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 34            4.9          3.1           1.5          0.1     Iris-setosa
# 37            4.9          3.1           1.5          0.1     Iris-setosa
# 142           5.8          2.7           5.1          1.9  Iris-virginica

# %%
dup = pd.DataFrame({
    'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
    'style': ['cup', 'cup', 'cup', 'pack', 'pack'],
    'rating': [4, 4, 3.5, 15, 5]
})

# %%
df[2:10]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
df.loc[5]
# Out:
# sepal_length            5.4
# sepal_width             3.9
# petal_length            1.7
# petal_width             0.4
# class           Iris-setosa
# Name: 5, dtype: object

# %%
df.iloc[5]
# Out:
# sepal_length            5.4
# sepal_width             3.9
# petal_length            1.7
# petal_width             0.4
# class           Iris-setosa
# Name: 5, dtype: object

# %%
df3.loc['f1']
# Out:
# Fruit_name    apple
# Quantity         10
# Unit_price      240
# Name: f1, dtype: object

# %%
df['petal_length']
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: petal_length, Length: 150, dtype: float64

# %%
df.iloc[5:10]['petal_length']
# Out:
# 5    1.7
# 6    1.4
# 7    1.5
# 8    1.4
# 9    1.5
# Name: petal_length, dtype: float64

# %%
df.loc[5:10]['petal_length']
# Out:
# 5     1.7
# 6     1.4
# 7     1.5
# 8     1.4
# 9     1.5
# 10    1.5
# Name: petal_length, dtype: float64

# %%
df.loc[[55, 60], ['sepal_width', 'petal_width']]
# Out:
#     sepal_width  petal_width
# 55          2.8          1.3
# 60          2.0          1.0

# %%
print(df['petal_length'].sum())
print(df['petal_length'].mean())
print(df['petal_length'].median())
# Out:
# 563.8
# 3.758666666666666
# 4.35

# %%
print(df['sepal_length'].min())
print(df['sepal_length'].max())
# Out:
# 4.3
# 7.9

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
df.plot()
plt.show()

# %%
df.plot(kind = 'scatter', x = 'sepal_length', y = 'petal_length')
plt.show()

# %%
df.plot(kind = 'scatter', x = 'petal_length', y = 'petal_width')
plt.show()

# %%
df.plot(kind = 'scatter', x = 'sepal_length', y = 'sepal_width')
plt.show()

# %%
df.plot(kind = 'scatter', x = 'petal_length', y = 'sepal_width')
plt.show()

# %%
df['sepal_length'].plot(kind='hist')
plt.show()
